# %%
import os
from dotenv import load_dotenv
from pinecone import Pinecone, ServerlessSpec

load_dotenv()

pc_api_key= os.getenv("PINECONE_API_KEY")
openai_api_key = os.getenv("OPENAI_API_KEY")


pc = Pinecone(api_key=pc_api_key)
client = os.getenv("OPENAI_API_KEY")

# %%
print(pc)
print(pc.list_indexes())
# Out:
# Pinecone(api_key='...aUdP', host='https://api.pinecone.io')
# IndexList([])

# %%
pc.create_index(
    name="test-index",
    dimension=1536,
    metric="cosine",
    spec=ServerlessSpec(
        cloud="aws",
        region="us-east-1"
    )
)
# Out:
# IndexModel(
#   name='test-index',
#   status='Ready',
#   host='https://test-index-1r5qdvm.svc.aped-4627-b74a.pinecone.io',
#   deployment=ManagedDeployment(cloud='aws', region='us-east-1', environment='aped-4627-b74a'),
#   deletion_protection='disabled',
#   schema=IndexSchema(fields=2 fields),
#   read_capacity=ReadCapacityOnDemandResponse(status=ReadCapacityStatus(state='Ready', current_shards=None, current_replicas=None, error_message=None)),)

# %%
print(pc.list_indexes())
# Out:
# IndexList([])

# %%
import sys

print(sys.executable)
# Out:
# c:\Users\User\OneDrive\Desktop\FinalProjectRAG\Pinecone indexes\.venv\Scripts\python.exe

# %%
from pinecone import Pinecone, ServerlessSpec

print("Pinecone imported successfully!")
# Out:
# Pinecone imported successfully!

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\User\OneDrive\Desktop\FinalProjectRAG\Pinecone indexes\.venv\Scripts\python.exe

# %%
vectors= [
    {"id":"1","values": [0.1,0.2,0.3]},
    {"id":"2","values": [0.2,0.3,0.4]},
    {"id":"3","values": [0.3,0.4,0.5]},
    {"id":"4","values": [0.4,0.5,0.6]},
    {"id":"5","values": [0.5,0.6,0.7]},
    {"id":"6","values": [0.6,0.7,0.8]},
    {"id":"7","values": [0.7,0.8,0.9]},
    {"id":"8","values": [0.8,0.9,1.0]},
    {"id":"9","values": [0.9,1.0,1.1]},
    {"id":"10","values": [1.0,1.1,1.2]},
]

# %%
is_valid = all(len(vector["values"]) == 3 for vector in vectors)

print(is_valid)
# Out:
# True

# %%
import os
from dotenv import load_dotenv
from pinecone import Pinecone

load_dotenv()

PINECONE_API_KEY = os.getenv("PINECONE_API_KEY")

pc = Pinecone(api_key=PINECONE_API_KEY)

print(pc)
# Out:
# Pinecone(api_key='...aUdP', host='https://api.pinecone.io')

# %%
pc = Pinecone(api_key=PINECONE_API_KEY)

# %%
index = pc.Index("test-index")

# %%
from pinecone import Pinecone, ServerlessSpec

# %%
pc = Pinecone(api_key=PINECONE_API_KEY)

# %%
pc.create_index(
    name="vector-test",
    dimension=3,
    metric="cosine",
    spec=ServerlessSpec(
        cloud="aws",
        region="us-east-1"
    )
)
# Out:
# IndexModel(
#   name='vector-test',
#   status='Ready',
#   host='https://vector-test-1r5qdvm.svc.aped-4627-b74a.pinecone.io',
#   deployment=ManagedDeployment(cloud='aws', region='us-east-1', environment='aped-4627-b74a'),
#   deletion_protection='disabled',
#   schema=IndexSchema(fields=2 fields),
#   read_capacity=ReadCapacityOnDemandResponse(status=ReadCapacityStatus(state='Ready', current_shards=None, current_replicas=None, error_message=None)),)
