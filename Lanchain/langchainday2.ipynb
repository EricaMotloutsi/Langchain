# %%
import sys

print(sys.executable)
# Out:
# c:\Users\User\OneDrive\Desktop\FinalProjectRAG\Lanchain\.venv\Scripts\python.exe

# %%
from langchain_core.prompts import PromptTemplate

template = "Explain {concept} in simple terms"

prompt = PromptTemplate(
    input_variables=["concept"],
    template=template
)

final_prompt = prompt.format(concept="Artificial Intelligence")

print(final_prompt)
# Out:
# Explain Artificial Intelligence in simple terms

# %%
import os
from dotenv import load_dotenv
from openai import OpenAI
import chromadb

# %%
# Load API Keys
# uv add scipy
# -----------------------------
load_dotenv()

api_key = os.getenv("OPENAI_API_KEY")

openai= OpenAI(api_key=api_key)

client = chromadb.PersistentClient(path="./chroma_db")

# %%
#modern import
from langchain_core.prompts import ChatPromptTemplate

# %%
from langchain_core.prompts import ChatPromptTemplate

# Create chat prompt template
chat_template = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful math teacher"),
    ("human", "What is {question}?")
])

# Generate formatted prompt
prompt = chat_template.invoke({
    "question": "5 + 10"
})

print(prompt)
# Out:
# messages=[SystemMessage(content='You are a helpful math teacher', additional_kwargs={}, response_metadata={}), HumanMessage(content='What is 5 + 10?', additional_kwargs={}, response_metadata={})]

# %%
import os
from dotenv import load_dotenv

from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate

# Load API key from .env
load_dotenv()

api_key = os.getenv("OPENAI_API_KEY")

# Create LLM
llm = ChatOpenAI(
    model="gpt-4o-mini",
    api_key=api_key
)

# Create chat template
chat_template = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful assistant"),
    ("human", "{question}")
])

# Create chain
chain = chat_template | llm

# Invoke chain
response = chain.invoke({
    "question": "What is Python?"
})

# Print response
print(response.content)
# Out:
# Python is a high-level, interpreted programming language known for its readability and simplicity. It was created by Guido van Rossum and first released in 1991. Python emphasizes code readability and allows programmers to express concepts in fewer lines of code compared to languages like C++ or Java.
#
# Key features of Python include:
#
# 1. **Ease of Learning**: Python has a straightforward syntax that is easy to understand for beginners, making it a popular choice for those new to programming.
#
# 2. **Interpreted Language**: Python code is executed line by line, which makes debugging easier and speeds up the development process as there's no need to compile the code before running it.
#
# 3. **Versatility**: Python is used in various domains such as web development (with frameworks like Django and Flask), data science (with libraries like Pandas, NumPy, and Scikit-learn), machine learning (with TensorFlow and PyTorch), automation, scripting, and more.
#
# 4. **Rich Ecosystem**: Python has a large standard library and a vast ecosystem of third-party packages available through the Python Package Index (PyPI), allowing developers to utilize pre-built functionalities and save time on development.
#
# 5. **Community Support**: Python has a large and active community, which provides extensive documentation, tutorials, and forums for troubleshooting and advice.
#
# 6. **Cross-Platform**: Python is available on various operating systems, including Windows, macOS, and Linux, which allows for its widespread adoption in different environments.
#
# 7. **Object-Oriented and Functional Programming**: Python supports multiple programming paradigms, including object-oriented, imperative, and functional programming, giving developers flexibility in how they structure their code.
#
# Overall, Python's combination of simplicity, versatility, and support makes it one of the most popular programming languages in the world.

# %%
#Exercise 2 — Chat Prompt Templates
import os
from dotenv import load_dotenv

from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate

load_dotenv()

api_key = os.getenv("OPENAI_API_KEY")

# Create model
llm = ChatOpenAI(
    model="gpt-4o-mini",
    api_key=api_key
)

# Create chat prompt template
prompt_template = ChatPromptTemplate.from_messages([
    (
        "system",
        "You are a geography expert that returns the colors present in a country's flag."
    ),
    ("human", "France"),
    ("ai", "blue, white, red"),
    ("human", "{country}")
])

# Create chain
llm_chain = prompt_template | llm

# Invoke chain
country = "Japan"

response = llm_chain.invoke({
    "country": country
})

print(response.content)
# Out:
# white, red
